# %% [markdown]
# # 번개장터 뉴발란스 992 데이터 추가 (2838건)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time 
import json


from bs4 import BeautifulStoneSoup
import requests

# %%
url  = f'https://api.bunjang.co.kr/api/1/find_v2.json?q=%EB%89%B4%EB%B0%9C%EB%9E%80%EC%8A%A4+992&order=score&page={1}&request_id=20211110171345&stat_device=w&n=100&stat_category_required=1&req_ref=search&version=4'

# %%
info = {"referer" : "https://m.bunjang.co.kr/" , "user-agent" :"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36"}

# %%
resp = requests.get( url ,headers = info)
resp
# Out:
# <Response [200]>

# %%
data  = json.loads(resp.text) 
data
# Out:
# {'result': 'success',
#  'no_result': False,
#  'no_result_type': None,
#  'no_result_message': None,
#  'ad_more_info': False,
#  'ad_products': [],
#  'list': [{'ad': False,
#    'bizseller': False,
#    'checkout': False,
#    'contact_hope': False,
#    'free_shipping': False,
#    'is_adult': False,
#    'is_super_up_shop': None,
#    'location': '',
#    'max_cpc': None,
#    'name': '뉴발란스992 m992ea 225 트리플블랙 새상품',
#    'num_comment': '0',
#    'num_faved': '1',
#    'only_neighborhood': False,
#    'outlink_url': '',
#    'pid': '168696850',
#    'price': '300000',
#    'product_image': 'https://media.bunjang.co.kr/product/168696850_1_1636385849_w{res}.jpg',
#    'pu_id': None,
#    'ref_campaign': None,
#    'ref_code': 'soldout_test_v2:B',
#    'ref_medium': None,
#    'ref_content': '',
#    'ref_source': '',
#    'status': '0',
#    'style': '',
#    'super_up': None,
#    'tag': '뉴발란스992 트리플블랙',
#    'uid': '76232245',
#    'update_time': 1636505696,
#    'used': 1,
# ...

# %%
info = {"referer" : "https://m.bunjang.co.kr/" , "user-agent" :"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36"}

n_df = pd.DataFrame()

for i in range(1,30) :
    
    
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(5)
    time.sleep(a)
    
    
    url  = f'https://api.bunjang.co.kr/api/1/find_v2.json?q=%EB%89%B4%EB%B0%9C%EB%9E%80%EC%8A%A4+992&order=score&page={i}&request_id=20211110171345&stat_device=w&n=100&stat_category_required=1&req_ref=search&version=4'
    print(f'{i} 크롤링중 입니다. 기다려주세요.')
          
    resp = requests.get( url ,headers = info)
    data  = json.loads(resp.text) 
    
    df = pd.DataFrame(data["list"])
    n_df = pd.concat([df, n_df] , ignore_index = True )
# Out:
# 1 크롤링중 입니다. 기다려주세요.
# 2 크롤링중 입니다. 기다려주세요.
# 3 크롤링중 입니다. 기다려주세요.
# 4 크롤링중 입니다. 기다려주세요.
# 5 크롤링중 입니다. 기다려주세요.
# 6 크롤링중 입니다. 기다려주세요.
# 7 크롤링중 입니다. 기다려주세요.
# 8 크롤링중 입니다. 기다려주세요.
# 9 크롤링중 입니다. 기다려주세요.
# 10 크롤링중 입니다. 기다려주세요.
# 11 크롤링중 입니다. 기다려주세요.
# 12 크롤링중 입니다. 기다려주세요.
# 13 크롤링중 입니다. 기다려주세요.
# 14 크롤링중 입니다. 기다려주세요.
# 15 크롤링중 입니다. 기다려주세요.
# 16 크롤링중 입니다. 기다려주세요.
# 17 크롤링중 입니다. 기다려주세요.
# 18 크롤링중 입니다. 기다려주세요.
# 19 크롤링중 입니다. 기다려주세요.
# 20 크롤링중 입니다. 기다려주세요.
# 21 크롤링중 입니다. 기다려주세요.
# 22 크롤링중 입니다. 기다려주세요.
# 23 크롤링중 입니다. 기다려주세요.
# 24 크롤링중 입니다. 기다려주세요.
# 25 크롤링중 입니다. 기다려주세요.
# 26 크롤링중 입니다. 기다려주세요.
# 27 크롤링중 입니다. 기다려주세요.
# 28 크롤링중 입니다. 기다려주세요.
# 29 크롤링중 입니다. 기다려주세요.

# %%
n_df
# Out:
#          ad  bizseller  checkout  contact_hope  free_shipping  is_adult  \
# 0     False      False     False         False           True     False
# 1     False      False     False         False          False     False
# 2     False      False     False         False          False     False
# 3     False      False     False         False          False     False
# 4     False      False     False         False          False     False
# ...     ...        ...       ...           ...            ...       ...
# 2731  False      False     False         False           True     False
# 2732  False      False     False         False          False     False
# 2733  False      False     False         False           True     False
# 2734  False      False     False         False           True     False
# 2735  False      False     False         False          False     False
#
#      is_super_up_shop          location max_cpc                       name  \
# ...
